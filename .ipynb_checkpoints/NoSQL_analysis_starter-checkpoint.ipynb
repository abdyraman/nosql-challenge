# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": {"$gt": 20}}


# Use count_documents to display the number of documents in the result
results=establishments.count_documents(query)
print(results)

# Display the first document in the results using pprint
establishments.find_one(query)
# Out:
# 7
# {'_id': ObjectId('64653d84e0608856cd55a5f3'),
#  'FHRSID': 1349147,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '21/00036/COM',
#  'BusinessName': 'Inferno',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'AddressLine1': 'Skyline Hotel',
#  'AddressLine2': 'Chelmsford Road',
#  'AddressLine3': 'Barnston',
#  'AddressLine4': 'Dunmow',
#  'PostCode': 'CM6 1LP',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2022-01-27T00:00:00',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'scores': {'Hygiene': 25, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.383023, 'latitude': 51.85643},
#  'RightToReply': '',
#  'Distance': 4650.02974294374,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'http://api.ratings.food.gov.uk/establishments/1349147'}]}

# %%
import pandas as pd
# Convert the result to a Pandas DataFrame
hygiene_results = list(establishments.find(query))
hygiene_df = pd.DataFrame(hygiene_results)

# Display the number of rows in the DataFrame
print(hygiene_df.shape[0])

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# 7
#                         _id   FHRSID  ChangesByServerID  \
# 0  64653d84e0608856cd55a5f3  1349147                  0
# 1  64653d84e0608856cd55b02d   785554                  0
# 2  64653d84e0608856cd55b1e4   514156                  0
# 3  64653d84e0608856cd55b1f7   514651                  0
# 4  64653d84e0608856cd55b230   514221                  0
# 5  64653d84e0608856cd55b276   552296                  0
# 6  64653d84e0608856cd55b3ee  1351355                  0
#
#   LocalAuthorityBusinessID                                   BusinessName  \
# 0             21/00036/COM                                        Inferno
# 1            08/00054/FOOD                       Stratford News And Wines
# 2                      147                            The Plough & Harrow
# 3                    47178                                         Chicks
# 4                    17220  The Continental Food Exchange/TFC Leytonstone
# 5                    63877                                            O42
# 6                   348976                       Busy Bees at Leytonstone
#
#               BusinessType  BusinessTypeID                      AddressLine1  \
# 0   Takeaway/sandwich shop            7844                     Skyline Hotel
# 1        Retailers - other            4613                  107 Romford Road
# 2        Pub/bar/nightclub            7843
# 3   Takeaway/sandwich shop            7844
# 4        Retailers - other            4613
# 5  Restaurant/Cafe/Canteen               1
# 6          Caring Premises               5  Whipps Cross University Hospital
#
#                     AddressLine2 AddressLine3  ...  \
# 0                Chelmsford Road     Barnston  ...
# 1                      Stratford       London  ...
# 2      419 High Road Leytonstone               ...
# 3                  497 High Road               ...
# 4  647-661 High Road Leytonstone               ...
# 5      885 High Road Leytonstone               ...
# 6              Whipps Cross Road               ...
#
#              LocalAuthorityWebSite                LocalAuthorityEmailAddress  \
# 0     http://www.uttlesford.gov.uk     environmentalhealth@uttlesford.gov.uk
# 1        https://www.newham.gov.uk                        food@newham.gov.uk
# 2  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 3  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 4  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 5  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 6  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 25, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 25, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
#
#                                             geocode RightToReply     Distance  \
# 0     {'longitude': 0.383023, 'latitude': 51.85643}               4650.029743
# 1    {'longitude': 0.008382, 'latitude': 51.542772}               4652.047527
# 2    {'longitude': 0.006434, 'latitude': 51.558138}               4652.681025
# 3  {'longitude': 0.0071334, 'latitude': 51.5593505}               4652.699935
# 4    {'longitude': 0.009602, 'latitude': 51.563902}               4652.776654
# 5    {'longitude': 0.014137, 'latitude': 51.570848}               4652.865838
# 6  {'longitude': 0.0034702, 'latitude': 51.5774342}               4653.495442
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6             True  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [7 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = establishments.aggregate([{"$match": {"AddressLine3": "London", "RatingValue": {"$gte": 4}}}])

# Use count_documents to display the number of documents in the result
results=establishments.count_documents(query)
print(results)

# # Display the first document in the results using pprint
establishments.find_one(query)

# %%
# Convert the result to a Pandas DataFrame
restraunts = list(establishments.find(query))
df = pd.DataFrame(restraunts)

# Display the number of rows in the DataFrame
print(df.shape[0])

# Display the first 10 rows of the DataFrame
df.tail(10)

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude =  51.4925572
longitude = 0.0448072

query = {
    "geocode.latitude": {"$gt": latitude - degree_search, "$lt": latitude + degree_search},
    "geocode.longitude": {"$gt": longitude - degree_search, "$lt": longitude + degree_search},
    "RatingValue": 5
    
}
sort = [("scores.Hygiene", 1)]

# Find and print the matching documents
results = list(establishments.find(query).sort(sort))
pprint(results)
# Out:
# [{'AddressLine1': '21 Cemetery Lane',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Charlton Park Care Centre',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4648.34626826654,
#   'FHRSID': 694166,
#   'LocalAuthorityBusinessID': 'PI/000029477',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8DZ',
#   'RatingDate': '2021-07-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559e37'),
#   'geocode': {'latitude': 51.4826106, 'longitude': 0.0494751},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694166',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '56 Hillreach',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Brown Shuga Dumplin',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4648.418916105363,
#   'FHRSID': 1338515,
#   'LocalAuthorityBusinessID': '14127',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 4AL',
#   'RatingDate': '2022-03-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559e71'),
#   'geocode': {'latitude': 51.4859307, 'longitude': 0.0508167},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1338515',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '56 Hillreach',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Luv Jerk',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4648.418916105363,
#   'FHRSID': 1338516,
#   'LocalAuthorityBusinessID': '14128',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 4AL',
#   'RatingDate': '2022-03-23T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559e72'),
#   'geocode': {'latitude': 51.4859307, 'longitude': 0.0508167},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1338516',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '68 Little Heath',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Little Heath Lodge',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4648.438660080946,
#   'FHRSID': 694502,
#   'LocalAuthorityBusinessID': 'PI/000092304',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8BH',
#   'RatingDate': '2022-06-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559e82'),
#   'geocode': {'latitude': 51.4845454, 'longitude': 0.0488849},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694502',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Cardwell School Frances Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Tree Tops Clubs',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4648.509453758986,
#   'FHRSID': 1392054,
#   'LocalAuthorityBusinessID': '14545',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5LP',
#   'RatingDate': '2021-08-06T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559ef9'),
#   'geocode': {'latitude': 51.4907035827637, 'longitude': 0.0531269982457161},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1392054',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Woodhill Primary School Woodhill',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Woodhill Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4648.598564208742,
#   'FHRSID': 694914,
#   'LocalAuthorityBusinessID': 'PI/000164419',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5JE',
#   'RatingDate': '2021-06-23T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559f64'),
#   'geocode': {'latitude': 51.489315032959, 'longitude': 0.0492900013923645},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694914',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '1 Samuel Close',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Choice Support',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4648.6146448992895,
#   'FHRSID': 695394,
#   'LocalAuthorityBusinessID': 'PI/000184572',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5LR',
#   'RatingDate': '2021-02-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559f8a'),
#   'geocode': {'latitude': 51.4912123, 'longitude': 0.0507541},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695394',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '2 Samuel Close',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Choice Support',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4648.614328885469,
#   'FHRSID': 695396,
#   'LocalAuthorityBusinessID': 'PI/000184574',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5LR',
#   'RatingDate': '2021-06-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559f97'),
#   'geocode': {'latitude': 51.4909029, 'longitude': 0.0504521},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695396',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '134 Woolwich Church Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'TJ & Sons Supermarket',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.628168745716,
#   'FHRSID': 694915,
#   'LocalAuthorityBusinessID': 'PI/000165795',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NQ',
#   'RatingDate': '2021-06-23T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559fa6'),
#   'geocode': {'latitude': 51.4920494, 'longitude': 0.0512239},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694915',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '132 Woolwich Church Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': "Mimi's Kitchen",
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4648.620487964715,
#   'FHRSID': 1265336,
#   'LocalAuthorityBusinessID': '13617',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NQ',
#   'RatingDate': '2020-11-25T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559faa'),
#   'geocode': {'latitude': 51.4919128, 'longitude': 0.0512973},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1265336',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Time Court Woodland Terrace',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Time Court Nursing Home',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4648.660544370224,
#   'FHRSID': 695067,
#   'LocalAuthorityBusinessID': 'PI/000174863',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8EX',
#   'RatingDate': '2021-10-12T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559fcd'),
#   'geocode': {'latitude': 51.4894943237305, 'longitude': 0.0477709993720055},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695067',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '87 Antelope Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Busy Bees at Greenwich',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4648.66367574451,
#   'FHRSID': 695554,
#   'LocalAuthorityBusinessID': 'PI/000188451',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5QG',
#   'RatingDate': '2021-06-23T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559fd1'),
#   'geocode': {'latitude': 51.493873, 'longitude': 0.0520817},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695554',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Unit 9a Commonwealth Buildings Woolwich Church Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Top Specialist Cakes and Snacks',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'ChangesByServerID': 0,
#   'Distance': 4648.780424411259,
#   'FHRSID': 744732,
#   'LocalAuthorityBusinessID': 'PI/000196781',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NS',
#   'RatingDate': '2020-02-03T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a049'),
#   'geocode': {'latitude': 51.4932503, 'longitude': 0.0482557},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/744732',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 2 To 3 Commonwealth Buildings Woolwich Church Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': "Mimi's Kitchen",
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4648.7825792776475,
#   'FHRSID': 1250851,
#   'LocalAuthorityBusinessID': '13439',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NS',
#   'RatingDate': '2021-02-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a04d'),
#   'geocode': {'latitude': 51.4930076599121, 'longitude': 0.0479529984295368},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1250851',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 9 L And Unit M Commonwealth Buildings Woolwich Church '
#                   'Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Deluscious Catering Ltd',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.796598139947,
#   'FHRSID': 1025347,
#   'LocalAuthorityBusinessID': 'PI/000202421',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NS',
#   'RatingDate': '2022-03-25T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a05b'),
#   'geocode': {'latitude': 51.4930229187012, 'longitude': 0.0475840009748936},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1025347',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Thorntree School Pound Park Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Thorntree School Breakfast Club',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4648.813030376201,
#   'FHRSID': 843826,
#   'LocalAuthorityBusinessID': 'PI/000199062',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AE',
#   'RatingDate': '2022-03-10T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a06c'),
#   'geocode': {'latitude': 51.4875144958496, 'longitude': 0.0416040010750294},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/843826',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Pound Park Nursery School Pound Park Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Pound Park Nursery School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4648.87431914686,
#   'FHRSID': 1386916,
#   'LocalAuthorityBusinessID': '14507',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AF',
#   'RatingDate': '2022-02-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a097'),
#   'geocode': {'latitude': 51.4880294799805, 'longitude': 0.0404409989714623},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1386916',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 11 Lansdowne Workshops Lansdowne Mews',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Boulangerie Jade Limited',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'ChangesByServerID': 0,
#   'Distance': 4648.876904027025,
#   'FHRSID': 984129,
#   'LocalAuthorityBusinessID': 'PI/000203336',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AZ',
#   'RatingDate': '2021-07-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a098'),
#   'geocode': {'latitude': 51.4849191, 'longitude': 0.0372489},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/984129',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Unit 13 Lansdowne Workshops Lansdowne Mews',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Drings Ltd',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'ChangesByServerID': 0,
#   'Distance': 4648.876904027025,
#   'FHRSID': 695665,
#   'LocalAuthorityBusinessID': 'PI/000191348',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AZ',
#   'RatingDate': '2021-06-29T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a099'),
#   'geocode': {'latitude': 51.4849191, 'longitude': 0.0372489},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695665',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 3 Lansdowne Workshops Lansdowne Mews',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Italian Recipe',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.876904027025,
#   'FHRSID': 1228349,
#   'LocalAuthorityBusinessID': '13361',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AZ',
#   'RatingDate': '2021-09-07T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a09d'),
#   'geocode': {'latitude': 51.4849191, 'longitude': 0.0372489},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1228349',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 12 Lansdowne Workshops Lansdowne Mews',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Mydetoxdiet.co.uk',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'ChangesByServerID': 0,
#   'Distance': 4648.876904027025,
#   'FHRSID': 695585,
#   'LocalAuthorityBusinessID': 'PI/000189155',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AZ',
#   'RatingDate': '2020-03-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0a3'),
#   'geocode': {'latitude': 51.4849191, 'longitude': 0.0372489},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695585',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '821 Woolwich Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Greenwich',
#   'AddressLine4': '',
#   'BusinessName': 'CGL',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.892567925892,
#   'FHRSID': 694955,
#   'LocalAuthorityBusinessID': 'PI/000167428',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8LJ',
#   'RatingDate': '2019-01-28T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0b3'),
#   'geocode': {'latitude': 51.4924192, 'longitude': 0.044347},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694955',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'LCY Hotel',
#   'AddressLine2': '74 Albert Road',
#   'AddressLine3': 'North Woolwich',
#   'AddressLine4': 'London',
#   'BusinessName': 'London City Airport Hotel',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'ChangesByServerID': 0,
#   'Distance': 4648.910202776571,
#   'FHRSID': 1130158,
#   'LocalAuthorityBusinessID': '19/00398/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2DY',
#   'RatingDate': '2019-10-29T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0cf'),
#   'geocode': {'latitude': 51.5014953613281, 'longitude': 0.0529780015349388},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1130158',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Royal Oak 54 Charlton Lane',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'JWalks Grill',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.924827084417,
#   'FHRSID': 1350899,
#   'LocalAuthorityBusinessID': '14208',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8LA',
#   'RatingDate': '2021-05-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0db'),
#   'geocode': {'latitude': 51.488347, 'longitude': 0.0393753},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1350899',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Charlton Athletic Football Club Office The Valley Floyd '
#                   'Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'FOOD Club - Charlton',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.928815167058,
#   'FHRSID': 1357492,
#   'LocalAuthorityBusinessID': '14237',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8BL',
#   'RatingDate': '2021-05-14T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0e2'),
#   'geocode': {'latitude': 51.4862403869629, 'longitude': 0.037151999771595},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1357492',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Charlton Athletic Football Club Office The Valley Floyd '
#                   'Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'CACT',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.928815167058,
#   'FHRSID': 1289151,
#   'LocalAuthorityBusinessID': '13858',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8BL',
#   'RatingDate': '2020-10-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0f1'),
#   'geocode': {'latitude': 51.4862403869629, 'longitude': 0.037151999771595},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1289151',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Unit 7 Mellish Industrial Estate Harrington Way',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Sol Street food',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.97817869648,
#   'FHRSID': 1394247,
#   'LocalAuthorityBusinessID': '14603',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NR',
#   'RatingDate': '2021-09-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a104'),
#   'geocode': {'latitude': 51.4943765, 'longitude': 0.0439651},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1394247',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 2 Mellish Industrial Estate Harrington Way',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Doreen’s Jamaican homemade rum cakes',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'ChangesByServerID': 0,
#   'Distance': 4648.97817869648,
#   'FHRSID': 1388272,
#   'LocalAuthorityBusinessID': '14526',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NR',
#   'RatingDate': '2022-01-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a105'),
#   'geocode': {'latitude': 51.4943765, 'longitude': 0.0439651},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1388272',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Unit 2b Mellish Industrial Estate Harrington Way',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Fragola Matta',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.9881416056605,
#   'FHRSID': 695179,
#   'LocalAuthorityBusinessID': 'PI/000177384',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2019-10-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a115'),
#   'geocode': {'latitude': 51.4946034677012, 'longitude': 0.0439198413515836},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695179',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 1 Mellish Industrial Estate Harrington Way',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Riverview Foods',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'ChangesByServerID': 0,
#   'Distance': 4648.9881416056605,
#   'FHRSID': 1359741,
#   'LocalAuthorityBusinessID': '14267',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2021-07-14T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a11c'),
#   'geocode': {'latitude': 51.4946034677012, 'longitude': 0.0439198413515836},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1359741',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Unit 3 Mellish Industrial Estate Harrington Way',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Ethiopian and Eritrean Cuisine',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.989328930507,
#   'FHRSID': 859297,
#   'LocalAuthorityBusinessID': 'PI/000199071',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NR',
#   'RatingDate': '2020-09-01T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a120'),
#   'geocode': {'latitude': 51.4944458007813, 'longitude': 0.0437289997935295},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/859297',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '1 - 2 Eastmoor Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Ades Ltd ( Ades Cash & Carry)',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4649.004714527218,
#   'FHRSID': 695042,
#   'LocalAuthorityBusinessID': 'PI/000173878',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8LX',
#   'RatingDate': '2022-05-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a124'),
#   'geocode': {'latitude': 51.4910113, 'longitude': 0.0398596},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695042',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Staff Canteen',
#   'AddressLine2': 'Thames Refinery',
#   'AddressLine3': 'Factory Road',
#   'AddressLine4': 'North Woolwich',
#   'BusinessName': 'Olive Catering At Tate & Lyle',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4649.130270747128,
#   'FHRSID': 1333653,
#   'LocalAuthorityBusinessID': '21/00024/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2EW',
#   'RatingDate': '2021-06-15T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a1ab'),
#   'geocode': {'latitude': 51.5009651184082, 'longitude': 0.0464110001921654},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1333653',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Unit 35 New Lydenburg Commercial Estate New Lydenburg '
#                   'Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 21',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4649.197199608006,
#   'FHRSID': 1415725,
#   'LocalAuthorityBusinessID': '14794',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8NE',
#   'RatingDate': '2021-10-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a20d'),
#   'geocode': {'latitude': 51.4918659, 'longitude': 0.0354412},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1415725',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Gatekeepers Office',
#   'AddressLine2': 'Thameside Industrial Estate',
#   'AddressLine3': 'Factory Road',
#   'AddressLine4': 'North Woolwich',
#   'BusinessName': 'Morning Glory',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4649.230906931844,
#   'FHRSID': 1047532,
#   'LocalAuthorityBusinessID': '18/00081/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2HB',
#   'RatingDate': '2020-03-07T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a25c'),
#   'geocode': {'latitude': 51.5009853, 'longitude': 0.0436719},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1047532',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Gatekeepers Office',
#   'AddressLine2': 'Thameside Industrial Estate',
#   'AddressLine3': 'Factory Road',
#   'AddressLine4': 'North Woolwich',
#   'BusinessName': 'Say Cheese',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4649.230906931844,
#   'FHRSID': 1130148,
#   'LocalAuthorityBusinessID': '19/00373/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2HB',
#   'RatingDate': '2020-02-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a263'),
#   'geocode': {'latitude': 51.5009853, 'longitude': 0.0436719},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1130148',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Etap Accor Hotel',
#   'AddressLine2': 'North Woolwich Road',
#   'AddressLine3': 'Silvertown',
#   'AddressLine4': 'London',
#   'BusinessName': 'IBIS Budget Hotel',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'ChangesByServerID': 0,
#   'Distance': 4649.367342122315,
#   'FHRSID': 667139,
#   'LocalAuthorityBusinessID': '72440/0000/1/000',
#   'LocalAuthorityCode': '525',
# ...
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Street Record',
#   'AddressLine2': 'Sandpit Road',
#   'AddressLine3': 'Dartford',
#   'AddressLine4': 'Kent',
#   'BusinessName': "CJ's Snackbar",
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4648.498705309629,
#   'FHRSID': 1407189,
#   'LocalAuthorityBusinessID': '21/00193/FPREM/D',
#   'LocalAuthorityCode': '181',
#   'LocalAuthorityEmailAddress': 'eh.admin@dartford.gov.uk',
#   'LocalAuthorityName': 'Dartford',
#   'LocalAuthorityWebSite': 'http://www.dartford.gov.uk/foodsafety/index.htm',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2021-11-03T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559ed7'),
#   'geocode': {'latitude': 51.486335182214, 'longitude': 0.0490357238143205},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1407189',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': '3 Samuel Close',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Choice Support',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4648.613945902368,
#   'FHRSID': 695395,
#   'LocalAuthorityBusinessID': 'PI/000184573',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5LR',
#   'RatingDate': '2021-06-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd559f84'),
#   'geocode': {'latitude': 51.4906817, 'longitude': 0.0502405},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695395',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': 'Block 2 Unit 8 Dockyard Industrial Estate Woolwich Church '
#                   'Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Neelas Home Ltd',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.700410406297,
#   'FHRSID': 1357491,
#   'LocalAuthorityBusinessID': '14236',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5PQ',
#   'RatingDate': '2021-07-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a00a'),
#   'geocode': {'latitude': 51.4933031, 'longitude': 0.0505023},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1357491',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': "Mcdonald's Ruston Road",
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': "McDonald's",
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4648.796598139947,
#   'FHRSID': 712606,
#   'LocalAuthorityBusinessID': 'PI/000194564',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 5NS',
#   'RatingDate': '2020-08-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a05c'),
#   'geocode': {'latitude': 51.4930229187012, 'longitude': 0.0475840009748936},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/712606',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Thorntree School Pound Park Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Thorntree Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4648.813030376201,
#   'FHRSID': 1386923,
#   'LocalAuthorityBusinessID': '14514',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AE',
#   'RatingDate': '2021-11-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a06f'),
#   'geocode': {'latitude': 51.4875144958496, 'longitude': 0.0416040010750294},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1386923',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Unit 15 Lansdowne Workshops Lansdowne Mews',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'MrsJFoods',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.876904027025,
#   'FHRSID': 695573,
#   'LocalAuthorityBusinessID': 'PI/000188517',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8AZ',
#   'RatingDate': '2022-05-18T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0a8'),
#   'geocode': {'latitude': 51.4849191, 'longitude': 0.0372489},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695573',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'St Catherines Church 698 Woolwich Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Greenwich',
#   'AddressLine4': '',
#   'BusinessName': 'Moksliukas Nursery',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4648.913738526371,
#   'FHRSID': 1100052,
#   'LocalAuthorityBusinessID': '12391',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8LQ',
#   'RatingDate': '2019-01-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0d5'),
#   'geocode': {'latitude': 51.4913399, 'longitude': 0.0426832},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1100052',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': '64 Charlton Lane',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Greenwich Living Options',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4648.920864993539,
#   'FHRSID': 694183,
#   'LocalAuthorityBusinessID': 'PI/000031111',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8LA',
#   'RatingDate': '2019-12-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0d9'),
#   'geocode': {'latitude': 51.4880685, 'longitude': 0.0392044},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694183',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': 'Royal Oak 54 Charlton Lane',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Royal Oak',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4648.924827084417,
#   'FHRSID': 694182,
#   'LocalAuthorityBusinessID': 'PI/000031096',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE7 8LA',
#   'RatingDate': '2021-07-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a0de'),
#   'geocode': {'latitude': 51.488347, 'longitude': 0.0393753},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694182',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': 'Trinity Wharf Mellish Industrial Estate Harrington Way',
#   'AddressLine2': '',
#   'AddressLine3': 'Woolwich',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Arts Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.983609613946,
#   'FHRSID': 695471,
#   'LocalAuthorityBusinessID': 'PI/000186503',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2022-06-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a117'),
#   'geocode': {'latitude': 51.4948506, 'longitude': 0.0442922},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695471',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Community Food Enterprise Ltd',
#   'AddressLine2': 'Unit 4 Ground Floor',
#   'AddressLine3': 'Thameside Industrial Estate',
#   'AddressLine4': 'Factory Road',
#   'BusinessName': 'Community Food Enterprise Ltd -fruit & Veg - Juice Bar',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4649.228031043185,
#   'FHRSID': 830619,
#   'LocalAuthorityBusinessID': '09/00016/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2HB',
#   'RatingDate': '2019-03-31T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a252'),
#   'geocode': {'latitude': 51.500877, 'longitude': 0.043642},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/830619',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '3 Herringham Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Team Sport Indoor Karting',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4649.288970692189,
#   'FHRSID': 695695,
#   'LocalAuthorityBusinessID': 'PI/000192146',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2021-07-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64653d84e0608856cd55a2fb'),
#   'geocode': {'latitude': 51.4943139, 'longitude': 0.0353825},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695695',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}]

# %%
# Convert the result to a Pandas DataFrame
restraunts_nearby = list(establishments.find(query))
restraunts_nearby_df = pd.DataFrame(restraunts_nearby )

# Display the number of rows in the DataFrame
print(restraunts_nearby_df.shape[0])

# Display the first 10 rows of the DataFrame
restraunts_nearby_df.tail(10)
# Out:
# 51
#                          _id   FHRSID  ChangesByServerID  \
# 41  64653d84e0608856cd55a11c  1359741                  0
# 42  64653d84e0608856cd55a120   859297                  0
# 43  64653d84e0608856cd55a124   695042                  0
# 44  64653d84e0608856cd55a1ab  1333653                  0
# 45  64653d84e0608856cd55a20d  1415725                  0
# 46  64653d84e0608856cd55a252   830619                  0
# 47  64653d84e0608856cd55a25c  1047532                  0
# 48  64653d84e0608856cd55a263  1130148                  0
# 49  64653d84e0608856cd55a2fb   695695                  0
# 50  64653d84e0608856cd55a36b   667139                  0
#
#    LocalAuthorityBusinessID  \
# 41                    14267
# 42             PI/000199071
# 43             PI/000173878
# 44            21/00024/FOOD
# 45                    14794
# 46            09/00016/FOOD
# 47            18/00081/FOOD
# 48            19/00373/FOOD
# 49             PI/000192146
# 50         72440/0000/1/000
#
#                                          BusinessName  \
# 41                                    Riverview Foods
# 42                     Ethiopian and Eritrean Cuisine
# 43                      Ades Ltd ( Ades Cash & Carry)
# 44                      Olive Catering At Tate & Lyle
# 45                Howe and Co Fish and Chips - Van 21
# 46  Community Food Enterprise Ltd -fruit & Veg - J...
# 47                                      Morning Glory
# 48                                         Say Cheese
# 49                          Team Sport Indoor Karting
# 50                                  IBIS Budget Hotel
#
#                          BusinessType  BusinessTypeID  \
# 41              Manufacturers/packers            7839
# 42            Other catering premises            7841
# 43                  Retailers - other            4613
# 44            Other catering premises            7841
# 45                     Mobile caterer            7846
# 46            Other catering premises            7841
# 47                     Mobile caterer            7846
# 48                     Mobile caterer            7846
# 49            Restaurant/Cafe/Canteen               1
# 50  Hotel/bed & breakfast/guest house            7842
#
#                                          AddressLine1  \
# 41    Unit 1 Mellish Industrial Estate Harrington Way
# 42    Unit 3 Mellish Industrial Estate Harrington Way
# 43                              1 - 2 Eastmoor Street
# 44                                      Staff Canteen
# 45  Unit 35 New Lydenburg Commercial Estate New Ly...
# 46                      Community Food Enterprise Ltd
# 47                                 Gatekeepers Office
# 48                                 Gatekeepers Office
# 49                                  3 Herringham Road
# 50                                   Etap Accor Hotel
#
#                    AddressLine2                 AddressLine3  ...  \
# 41                                                  Woolwich  ...
# 42                                                  Woolwich  ...
# 43                                                  Charlton  ...
# 44              Thames Refinery                 Factory Road  ...
# 45                                                  Charlton  ...
# 46          Unit 4 Ground Floor  Thameside Industrial Estate  ...
# 47  Thameside Industrial Estate                 Factory Road  ...
# 48  Thameside Industrial Estate                 Factory Road  ...
# 49                                                  Charlton  ...
# 50          North Woolwich Road                   Silvertown  ...
#
#                LocalAuthorityWebSite    LocalAuthorityEmailAddress  \
# 41  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 42  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 43  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 44         https://www.newham.gov.uk            food@newham.gov.uk
# 45  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 46         https://www.newham.gov.uk            food@newham.gov.uk
# 47         https://www.newham.gov.uk            food@newham.gov.uk
# 48         https://www.newham.gov.uk            food@newham.gov.uk
# 49  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 50         https://www.newham.gov.uk            food@newham.gov.uk
#
#                                                scores  SchemeType  \
# 41  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 42  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 43  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 44  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 45  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 46  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 47  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 48  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 49  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 50  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                               geocode RightToReply  \
# 41  {'longitude': 0.0439198413515836, 'latitude': ...
# 42  {'longitude': 0.0437289997935295, 'latitude': ...
# 43   {'longitude': 0.0398596, 'latitude': 51.4910113}
# 44  {'longitude': 0.0464110001921654, 'latitude': ...
# 45   {'longitude': 0.0354412, 'latitude': 51.4918659}
# 46     {'longitude': 0.043642, 'latitude': 51.500877}
# 47   {'longitude': 0.0436719, 'latitude': 51.5009853}
# 48   {'longitude': 0.0436719, 'latitude': 51.5009853}
# 49   {'longitude': 0.0353825, 'latitude': 51.4943139}
# 50      {'longitude': 0.041211, 'latitude': 51.50226}
#
#        Distance NewRatingPending  \
# 41  4648.988142            False
# 42  4648.989329            False
# 43  4649.004715            False
# 44  4649.130271            False
# 45  4649.197200            False
# 46  4649.228031            False
# 47  4649.230907            False
# 48  4649.230907            False
# 49  4649.288971            False
# 50  4649.367342            False
#
#                                                  meta  \
# 41  {'dataSource': None, 'extractDate': '0001-01-0...
# 42  {'dataSource': None, 'extractDate': '0001-01-0...
# 43  {'dataSource': None, 'extractDate': '0001-01-0...
# 44  {'dataSource': None, 'extractDate': '0001-01-0...
# 45  {'dataSource': None, 'extractDate': '0001-01-0...
# 46  {'dataSource': None, 'extractDate': '0001-01-0...
# 47  {'dataSource': None, 'extractDate': '0001-01-0...
# 48  {'dataSource': None, 'extractDate': '0001-01-0...
# 49  {'dataSource': None, 'extractDate': '0001-01-0...
# 50  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 41  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 42  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 43  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 44  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 45  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 46  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 47  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 48  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 49  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 50  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
]

# Print the first 10 results

cursor = establishments.aggregate(pipeline)
for i, result in enumerate(cursor):
    pprint(result)
    if i >= 9:
        break
# Out:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(list(establishments.aggregate(pipeline)))

# Display the number of rows in the DataFrame
print(df.shape[0])

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
