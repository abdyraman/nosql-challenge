# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": {"$gt": 20}}


# Use count_documents to display the number of documents in the result
results=establishments.count_documents(query)
print(results)

# Display the first document in the results using pprint
establishments.find_one(query)
# Out:
# 7
# {'_id': ObjectId('6461130c6fd0f653bea5da6e'),
#  'FHRSID': 1349147,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '21/00036/COM',
#  'BusinessName': 'Inferno',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'AddressLine1': 'Skyline Hotel',
#  'AddressLine2': 'Chelmsford Road',
#  'AddressLine3': 'Barnston',
#  'AddressLine4': 'Dunmow',
#  'PostCode': 'CM6 1LP',
#  'Phone': '',
#  'RatingValue': '0',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2022-01-27T00:00:00',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'scores': {'Hygiene': 25, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.383023', 'latitude': '51.85643'},
#  'RightToReply': '',
#  'Distance': 4650.02974294374,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'http://api.ratings.food.gov.uk/establishments/1349147'}]}

# %%
import pandas as pd
# Convert the result to a Pandas DataFrame
hygiene_results = list(establishments.find(query))
hygiene_df = pd.DataFrame(hygiene_results)

# Display the number of rows in the DataFrame
print(hygiene_df.shape[0])

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# 7
#                         _id   FHRSID  ChangesByServerID  \
# 0  6461130c6fd0f653bea5da6e  1349147                  0
# 1  6461130c6fd0f653bea5e4a9   785554                  0
# 2  6461130c6fd0f653bea5e658   514156                  0
# 3  6461130c6fd0f653bea5e665   514651                  0
# 4  6461130c6fd0f653bea5e69d   514221                  0
# 5  6461130c6fd0f653bea5e6e0   552296                  0
# 6  6461130c6fd0f653bea5e85e  1351355                  0
#
#   LocalAuthorityBusinessID                                   BusinessName  \
# 0             21/00036/COM                                        Inferno
# 1            08/00054/FOOD                       Stratford News And Wines
# 2                      147                            The Plough & Harrow
# 3                    47178                                         Chicks
# 4                    17220  The Continental Food Exchange/TFC Leytonstone
# 5                    63877                                            O42
# 6                   348976                       Busy Bees at Leytonstone
#
#               BusinessType  BusinessTypeID                      AddressLine1  \
# 0   Takeaway/sandwich shop            7844                     Skyline Hotel
# 1        Retailers - other            4613                  107 Romford Road
# 2        Pub/bar/nightclub            7843
# 3   Takeaway/sandwich shop            7844
# 4        Retailers - other            4613
# 5  Restaurant/Cafe/Canteen               1
# 6          Caring Premises               5  Whipps Cross University Hospital
#
#                     AddressLine2 AddressLine3  ...  \
# 0                Chelmsford Road     Barnston  ...
# 1                      Stratford       London  ...
# 2      419 High Road Leytonstone               ...
# 3                  497 High Road               ...
# 4  647-661 High Road Leytonstone               ...
# 5      885 High Road Leytonstone               ...
# 6              Whipps Cross Road               ...
#
#              LocalAuthorityWebSite                LocalAuthorityEmailAddress  \
# 0     http://www.uttlesford.gov.uk     environmentalhealth@uttlesford.gov.uk
# 1        https://www.newham.gov.uk                        food@newham.gov.uk
# 2  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 3  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 4  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 5  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 6  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 25, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 25, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': '0.383023', 'latitude': '51.85643'}
# 1  {'longitude': '0.008382', 'latitude': '51.5427...
# 2  {'longitude': '0.006434', 'latitude': '51.5581...
# 3  {'longitude': '0.0071334', 'latitude': '51.559...
# 4  {'longitude': '0.009602', 'latitude': '51.5639...
# 5  {'longitude': '0.014137', 'latitude': '51.5708...
# 6  {'longitude': '0.0034702', 'latitude': '51.577...
#
#       Distance NewRatingPending  \
# 0  4650.029743            False
# 1  4652.047527            False
# 2  4652.681025            False
# 3  4652.699935            False
# 4  4652.776654            False
# 5  4652.865838            False
# 6  4653.495442             True
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [7 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = establishments.aggregate([{"$match": {"AddressLine3": "London", "RatingValue": {"$gte": 4}}}])

# Use count_documents to display the number of documents in the result
results=establishments.count_documents(query)
# print(results)

# # Display the first document in the results using pprint
# establishments.find_one(query)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# /var/folders/xq/xdbqztz92zs24q39hvzwj65m0000gn/T/ipykernel_21727/465681730.py in <module>
#       3
#       4 # Use count_documents to display the number of documents in the result
# ----> 5 results=establishments.count_documents(query)
#       6 # print(results)
#       7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/collection.py in count_documents(self, filter, session, **kwargs)
#    1824             return result['n']
#    1825
# -> 1826         return self.__database.client._retryable_read(
#    1827             _cmd, self._read_preference_for(session), session)
#    1828
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1523                         # not support retryable reads, raise the last error.
#    1524                         raise last_error
# -> 1525                     return func(session, server, sock_info, secondary_ok)
#    1526             except ServerSelectionTimeoutError:
#    1527                 if retrying:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/collection.py in _cmd(session, server, sock_info, secondary_ok)
#    1818
#    1819         def _cmd(session, server, sock_info, secondary_ok):
# -> 1820             result = self._aggregate_one_result(
#    1821                 sock_info, secondary_ok, cmd, collation, session)
#    1822             if not result:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/collection.py in _aggregate_one_result(self, sock_info, secondary_ok, cmd, collation, session)
#    1683             self, sock_info, secondary_ok, cmd, collation, session):
#    1684         """Internal helper to run an aggregate that returns a single result."""
# -> 1685         result = self._command(
#    1686             sock_info,
#    1687             cmd,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/collection.py in _command(self, sock_info, command, secondary_ok, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     236         """
#     237         with self.__database.client._tmp_session(session) as s:
# --> 238             return sock_info.command(
#     239                 self.__database.name,
#     240                 command,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/pool.py in command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     724         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     725         except BaseException as error:
# --> 726             self._raise_connection_failure(error)
#     727
#     728     def send_message(self, message, max_doc_size):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/pool.py in command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708             self._raise_if_not_writable(unacknowledged)
#     709         try:
# --> 710             return command(self, dbname, spec, secondary_ok,
#     711                            self.is_mongos, read_preference, codec_options,
#     712                            session, client, check, allowable_errors,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/network.py in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     116         flags = _OpMsg.MORE_TO_COME if unacknowledged else 0
#     117         flags |= _OpMsg.EXHAUST_ALLOWED if exhaust_allowed else 0
# --> 118         request_id, msg, size, max_doc_size = message._op_msg(
#     119             flags, spec, dbname, read_preference, secondary_ok, check_keys,
#     120             codec_options, ctx=compression_ctx)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymongo/message.py in _op_msg(flags, command, dbname, read_preference, secondary_ok, check_keys, opts, ctx)
#     740             return _op_msg_compressed(
#     741                 flags, command, identifier, docs, check_keys, opts, ctx)
# --> 742         return _op_msg_uncompressed(
#     743             flags, command, identifier, docs, check_keys, opts)
#     744     finally:
#
# InvalidDocument: cannot encode object: <pymongo.command_cursor.CommandCursor object at 0x7fc3e2750b80>, of type: <class 'pymongo.command_cursor.CommandCursor'>

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# query = { "BusinessName": "Penang Flavours" }
# update = { '$set': { "geocode.latitude": 51.4925572, "geocode.longitude": 0.0448072} }
# establishments.update_one(query, update)


# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude =  51.4925572
longitude = 0.0448072

query = {
    "geocode.latitude": {"$gt": latitude - degree_search, "$lt": latitude + degree_search},
    "geocode.longitude": {"$gt": longitude - degree_search, "$lt": longitude + degree_search},
    "RatingValue": 5
    
}
sort = [("scores.Hygiene", 1)]

# Find and print the matching documents
results = list(establishments.find(query).sort(sort))
pprint(results)
# Out:
# []

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
]

# Print the first 10 results

cursor = establishments.aggregate(pipeline)
for i, result in enumerate(cursor):
    pprint(result)
    if i >= 9:
        break
# Out:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(list(establishments.aggregate(pipeline)))

# Display the number of rows in the DataFrame
print(df.shape[0])

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
